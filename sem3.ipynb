# %% [markdown]
# #Задание 1.
# 1. Скачать данные по ссылке
# https://www.kaggle.com/datasets/ionaskel/laptop-prices
# 2. Считать данные с помощью pandas
# 3. Вывести на экран первые 5 строк
# 1.4 Удалите признаки Memory и ScreenResolution

# %%
import pandas as pd
df = pd.read_csv('laptop_price.csv', sep= ',', encoding= 'windows-1251')
df.head(5)
# Out:
#    laptop_ID Company      Product   TypeName  Inches  \
# 0          1   Apple  MacBook Pro  Ultrabook    13.3
# 1          2   Apple  Macbook Air  Ultrabook    13.3
# 2          3      HP       250 G6   Notebook    15.6
# 3          4   Apple  MacBook Pro  Ultrabook    15.4
# 4          5   Apple  MacBook Pro  Ultrabook    13.3
#
#                      ScreenResolution                         Cpu   Ram  \
# 0  IPS Panel Retina Display 2560x1600        Intel Core i5 2.3GHz   8GB
# 1                            1440x900        Intel Core i5 1.8GHz   8GB
# 2                   Full HD 1920x1080  Intel Core i5 7200U 2.5GHz   8GB
# 3  IPS Panel Retina Display 2880x1800        Intel Core i7 2.7GHz  16GB
# 4  IPS Panel Retina Display 2560x1600        Intel Core i5 3.1GHz   8GB
#
#                 Memory                           Gpu  OpSys  Weight  \
# 0            128GB SSD  Intel Iris Plus Graphics 640  macOS  1.37kg
# 1  128GB Flash Storage        Intel HD Graphics 6000  macOS  1.34kg
# 2            256GB SSD         Intel HD Graphics 620  No OS  1.86kg
# 3            512GB SSD            AMD Radeon Pro 455  macOS  1.83kg
# 4            256GB SSD  Intel Iris Plus Graphics 650  macOS  1.37kg
#
#    Price_euros
# 0      1339.69
# 1       898.94
# 2       575.00
# 3      2537.45
# 4      1803.60

# %% [markdown]
# 1.1 Создать новый признак Cpu_Company, который будет
# содержать только название фирмы, которая произвела CPU

# %%
df['Cpu_Company']=df['Cpu'].apply(lambda x: x.split(" "[0]))
df.head(5)
# Out:
#    laptop_ID Company      Product   TypeName  Inches  \
# 0          1   Apple  MacBook Pro  Ultrabook    13.3
# 1          2   Apple  Macbook Air  Ultrabook    13.3
# 2          3      HP       250 G6   Notebook    15.6
# 3          4   Apple  MacBook Pro  Ultrabook    15.4
# 4          5   Apple  MacBook Pro  Ultrabook    13.3
#
#                      ScreenResolution                         Cpu   Ram  \
# 0  IPS Panel Retina Display 2560x1600        Intel Core i5 2.3GHz   8GB
# 1                            1440x900        Intel Core i5 1.8GHz   8GB
# 2                   Full HD 1920x1080  Intel Core i5 7200U 2.5GHz   8GB
# 3  IPS Panel Retina Display 2880x1800        Intel Core i7 2.7GHz  16GB
# 4  IPS Panel Retina Display 2560x1600        Intel Core i5 3.1GHz   8GB
#
#                 Memory                           Gpu  OpSys  Weight  \
# 0            128GB SSD  Intel Iris Plus Graphics 640  macOS  1.37kg
# 1  128GB Flash Storage        Intel HD Graphics 6000  macOS  1.34kg
# 2            256GB SSD         Intel HD Graphics 620  No OS  1.86kg
# 3            512GB SSD            AMD Radeon Pro 455  macOS  1.83kg
# 4            256GB SSD  Intel Iris Plus Graphics 650  macOS  1.37kg
#
#    Price_euros                       Cpu_Company
# 0      1339.69         [Intel, Core, i5, 2.3GHz]
# 1       898.94         [Intel, Core, i5, 1.8GHz]
# 2       575.00  [Intel, Core, i5, 7200U, 2.5GHz]
# 3      2537.45         [Intel, Core, i7, 2.7GHz]
# 4      1803.60         [Intel, Core, i5, 3.1GHz]

# %% [markdown]
# 1.2 Создать новый признак Memory_Amount, который будет
# содержать только количество Gb памяти без указания типа
# носителя

# %%
def memory(memoru_str):
    gb=memoru_str.split(' ')[0]
    if gb.endswith('GB'):
        gb=float(gb[:-2])
    elif gb.endswith('TB'):
        gb=float(gb[:-2])*1024    
    return gb

df['Memory_Amount']=df['Memory'].apply(memory)
df.head(5)
# Out:
#    laptop_ID Company      Product   TypeName  Inches  \
# 0          1   Apple  MacBook Pro  Ultrabook    13.3
# 1          2   Apple  Macbook Air  Ultrabook    13.3
# 2          3      HP       250 G6   Notebook    15.6
# 3          4   Apple  MacBook Pro  Ultrabook    15.4
# 4          5   Apple  MacBook Pro  Ultrabook    13.3
#
#                      ScreenResolution                         Cpu   Ram  \
# 0  IPS Panel Retina Display 2560x1600        Intel Core i5 2.3GHz   8GB
# 1                            1440x900        Intel Core i5 1.8GHz   8GB
# 2                   Full HD 1920x1080  Intel Core i5 7200U 2.5GHz   8GB
# 3  IPS Panel Retina Display 2880x1800        Intel Core i7 2.7GHz  16GB
# 4  IPS Panel Retina Display 2560x1600        Intel Core i5 3.1GHz   8GB
#
#                 Memory                           Gpu  OpSys  Weight  \
# 0            128GB SSD  Intel Iris Plus Graphics 640  macOS  1.37kg
# 1  128GB Flash Storage        Intel HD Graphics 6000  macOS  1.34kg
# 2            256GB SSD         Intel HD Graphics 620  No OS  1.86kg
# 3            512GB SSD            AMD Radeon Pro 455  macOS  1.83kg
# 4            256GB SSD  Intel Iris Plus Graphics 650  macOS  1.37kg
#
#    Price_euros                       Cpu_Company  Memory_Amount
# 0      1339.69         [Intel, Core, i5, 2.3GHz]          128.0
# 1       898.94         [Intel, Core, i5, 1.8GHz]          128.0
# 2       575.00  [Intel, Core, i5, 7200U, 2.5GHz]          256.0
# 3      2537.45         [Intel, Core, i7, 2.7GHz]          512.0
# 4      1803.60         [Intel, Core, i5, 3.1GHz]          256.0

# %% [markdown]
# 1.3 Создать новый признак Memory_Type, который будет
# содержать только тип носителя (HDD/SDD/др.)

# %%
df['Memory_Type']=df['Memory'].apply(lambda x: x.split(" ")[1])
df.head(5)
# Out:
#    laptop_ID Company      Product   TypeName  Inches  \
# 0          1   Apple  MacBook Pro  Ultrabook    13.3
# 1          2   Apple  Macbook Air  Ultrabook    13.3
# 2          3      HP       250 G6   Notebook    15.6
# 3          4   Apple  MacBook Pro  Ultrabook    15.4
# 4          5   Apple  MacBook Pro  Ultrabook    13.3
#
#                      ScreenResolution                         Cpu   Ram  \
# 0  IPS Panel Retina Display 2560x1600        Intel Core i5 2.3GHz   8GB
# 1                            1440x900        Intel Core i5 1.8GHz   8GB
# 2                   Full HD 1920x1080  Intel Core i5 7200U 2.5GHz   8GB
# 3  IPS Panel Retina Display 2880x1800        Intel Core i7 2.7GHz  16GB
# 4  IPS Panel Retina Display 2560x1600        Intel Core i5 3.1GHz   8GB
#
#                 Memory                           Gpu  OpSys  Weight  \
# 0            128GB SSD  Intel Iris Plus Graphics 640  macOS  1.37kg
# 1  128GB Flash Storage        Intel HD Graphics 6000  macOS  1.34kg
# 2            256GB SSD         Intel HD Graphics 620  No OS  1.86kg
# 3            512GB SSD            AMD Radeon Pro 455  macOS  1.83kg
# 4            256GB SSD  Intel Iris Plus Graphics 650  macOS  1.37kg
#
#    Price_euros                       Cpu_Company  Memory_Amount Memory_Type
# 0      1339.69         [Intel, Core, i5, 2.3GHz]          128.0         SSD
# 1       898.94         [Intel, Core, i5, 1.8GHz]          128.0       Flash
# 2       575.00  [Intel, Core, i5, 7200U, 2.5GHz]          256.0         SSD
# 3      2537.45         [Intel, Core, i7, 2.7GHz]          512.0         SSD
# 4      1803.60         [Intel, Core, i5, 3.1GHz]          256.0         SSD

# %% [markdown]
# 1.4 Удалите признаки Memory и ScreenResolution

# %%
df1=df.copy()
df1.head(1)
# Out:
#    laptop_ID Company      Product   TypeName  Inches                   Cpu  \
# 0          1   Apple  MacBook Pro  Ultrabook    13.3  Intel Core i5 2.3GHz
#
#    Ram                           Gpu  OpSys  Weight  Price_euros  \
# 0  8GB  Intel Iris Plus Graphics 640  macOS  1.37kg      1339.69
#
#                  Cpu_Company  Memory_Amount Memory_Type
# 0  [Intel, Core, i5, 2.3GHz]          128.0         SSD

# %%
# df.drop(columns=['Memory', 'ScreenResolution'], inplace=True)
df.head(1)
# Out:
#    laptop_ID Company      Product   TypeName  Inches                   Cpu  \
# 0          1   Apple  MacBook Pro  Ultrabook    13.3  Intel Core i5 2.3GHz
#
#    Ram                           Gpu  OpSys  Weight  Price_euros  \
# 0  8GB  Intel Iris Plus Graphics 640  macOS  1.37kg      1339.69
#
#                  Cpu_Company  Memory_Amount Memory_Type
# 0  [Intel, Core, i5, 2.3GHz]          128.0         SSD

# %% [markdown]
# #Задание 2.
# 2.1 Создайте признак SSD, который изначально равен 0

# %%
df['SSD']=0
df.head(5)
# Out:
#    laptop_ID Company      Product   TypeName  Inches  \
# 0          1   Apple  MacBook Pro  Ultrabook    13.3
# 1          2   Apple  Macbook Air  Ultrabook    13.3
# 2          3      HP       250 G6   Notebook    15.6
# 3          4   Apple  MacBook Pro  Ultrabook    15.4
# 4          5   Apple  MacBook Pro  Ultrabook    13.3
#
#                           Cpu   Ram                           Gpu  OpSys  \
# 0        Intel Core i5 2.3GHz   8GB  Intel Iris Plus Graphics 640  macOS
# 1        Intel Core i5 1.8GHz   8GB        Intel HD Graphics 6000  macOS
# 2  Intel Core i5 7200U 2.5GHz   8GB         Intel HD Graphics 620  No OS
# 3        Intel Core i7 2.7GHz  16GB            AMD Radeon Pro 455  macOS
# 4        Intel Core i5 3.1GHz   8GB  Intel Iris Plus Graphics 650  macOS
#
#    Weight  Price_euros                       Cpu_Company  Memory_Amount  \
# 0  1.37kg      1339.69         [Intel, Core, i5, 2.3GHz]          128.0
# 1  1.34kg       898.94         [Intel, Core, i5, 1.8GHz]          128.0
# 2  1.86kg       575.00  [Intel, Core, i5, 7200U, 2.5GHz]          256.0
# 3  1.83kg      2537.45         [Intel, Core, i7, 2.7GHz]          512.0
# 4  1.37kg      1803.60         [Intel, Core, i5, 3.1GHz]          256.0
#
#   Memory_Type  SSD
# 0         SSD    0
# 1       Flash    0
# 2         SSD    0
# 3         SSD    0
# 4         SSD    0

# %% [markdown]
# 2.2 Поставьте в признаке SSD 1, если ноутбук
# действительно с типом носителя SSD

# %%
df.loc[df['Memory_Type'] == 'SSD', 'SSD']=1
df.head(5)
# Out:
#    laptop_ID Company      Product   TypeName  Inches  \
# 0          1   Apple  MacBook Pro  Ultrabook    13.3
# 1          2   Apple  Macbook Air  Ultrabook    13.3
# 2          3      HP       250 G6   Notebook    15.6
# 3          4   Apple  MacBook Pro  Ultrabook    15.4
# 4          5   Apple  MacBook Pro  Ultrabook    13.3
#
#                           Cpu   Ram                           Gpu  OpSys  \
# 0        Intel Core i5 2.3GHz   8GB  Intel Iris Plus Graphics 640  macOS
# 1        Intel Core i5 1.8GHz   8GB        Intel HD Graphics 6000  macOS
# 2  Intel Core i5 7200U 2.5GHz   8GB         Intel HD Graphics 620  No OS
# 3        Intel Core i7 2.7GHz  16GB            AMD Radeon Pro 455  macOS
# 4        Intel Core i5 3.1GHz   8GB  Intel Iris Plus Graphics 650  macOS
#
#    Weight  Price_euros                       Cpu_Company  Memory_Amount  \
# 0  1.37kg      1339.69         [Intel, Core, i5, 2.3GHz]          128.0
# 1  1.34kg       898.94         [Intel, Core, i5, 1.8GHz]          128.0
# 2  1.86kg       575.00  [Intel, Core, i5, 7200U, 2.5GHz]          256.0
# 3  1.83kg      2537.45         [Intel, Core, i7, 2.7GHz]          512.0
# 4  1.37kg      1803.60         [Intel, Core, i5, 3.1GHz]          256.0
#
#   Memory_Type  SSD
# 0         SSD    1
# 1       Flash    0
# 2         SSD    1
# 3         SSD    1
# 4         SSD    1

# %% [markdown]
# 2.3 Уберите в признаке Weight значения 'kg' и поменяйте его
# тип данных на вещественный

# %%
df['Weight']=df['Weight'].str.replace('kg', '').astype('float')
df.head(3)
# Out:
#    laptop_ID Company      Product   TypeName  Inches  \
# 0          1   Apple  MacBook Pro  Ultrabook    13.3
# 1          2   Apple  Macbook Air  Ultrabook    13.3
# 2          3      HP       250 G6   Notebook    15.6
#
#                           Cpu  Ram                           Gpu  OpSys  \
# 0        Intel Core i5 2.3GHz  8GB  Intel Iris Plus Graphics 640  macOS
# 1        Intel Core i5 1.8GHz  8GB        Intel HD Graphics 6000  macOS
# 2  Intel Core i5 7200U 2.5GHz  8GB         Intel HD Graphics 620  No OS
#
#    Weight  Price_euros                       Cpu_Company  Memory_Amount  \
# 0    1.37      1339.69         [Intel, Core, i5, 2.3GHz]          128.0
# 1    1.34       898.94         [Intel, Core, i5, 1.8GHz]          128.0
# 2    1.86       575.00  [Intel, Core, i5, 7200U, 2.5GHz]          256.0
#
#   Memory_Type  SSD
# 0         SSD    1
# 1       Flash    0
# 2         SSD    1

# %%
df.dtypes
# Out:
# laptop_ID          int64
# Company           object
# Product           object
# TypeName          object
# Inches           float64
# Cpu               object
# Ram               object
# Gpu               object
# OpSys             object
# Weight           float64
# Price_euros      float64
# Cpu_Company       object
# Memory_Amount    float64
# Memory_Type       object
# SSD                int64
# dtype: object

# %% [markdown]
# #Задание 3.
# Создайте датафрейм с клиентами:
# clients = pd.DataFrame({
#  'client_id': [45, 32, 67, 33, 43],
#  'laptop_id': [506, 398, 710, 120, 1999]
# })
# laptop_id - это индексы датафрейма с ноутбуками

# %%
clients = pd.DataFrame({
 'client_id': [45, 32, 67, 33, 43],
 'laptop_id': [506, 398, 710, 120, 1999]
})
clients
# Out:
#    client_id  laptop_id
# 0         45        506
# 1         32        398
# 2         67        710
# 3         33        120
# 4         43       1999

# %%
client_laptop=clients.set_index('laptop_id')
client_laptop
# Out:
#            client_id
# laptop_id
# 506               45
# 398               32
# 710               67
# 120               33
# 1999              43

# %%
df_laptop=df.set_index('laptop_ID')
df_laptop
# Out:
#           Company                              Product            TypeName  \
# laptop_ID
# 1           Apple                          MacBook Pro           Ultrabook
# 2           Apple                          Macbook Air           Ultrabook
# 3              HP                               250 G6            Notebook
# 4           Apple                          MacBook Pro           Ultrabook
# 5           Apple                          MacBook Pro           Ultrabook
# ...           ...                                  ...                 ...
# 1316       Lenovo                       Yoga 500-14ISK  2 in 1 Convertible
# 1317       Lenovo                       Yoga 900-13ISK  2 in 1 Convertible
# 1318       Lenovo                   IdeaPad 100S-14IBR            Notebook
# 1319           HP  15-AC110nv (i7-6500U/6GB/1TB/Radeon            Notebook
# 1320         Asus  X553SA-XX031T (N3050/4GB/500GB/W10)            Notebook
#
#            Inches                                   Cpu   Ram  \
# laptop_ID
# 1            13.3                  Intel Core i5 2.3GHz   8GB
# 2            13.3                  Intel Core i5 1.8GHz   8GB
# 3            15.6            Intel Core i5 7200U 2.5GHz   8GB
# 4            15.4                  Intel Core i7 2.7GHz  16GB
# 5            13.3                  Intel Core i5 3.1GHz   8GB
# ...           ...                                   ...   ...
# 1316         14.0            Intel Core i7 6500U 2.5GHz   4GB
# 1317         13.3            Intel Core i7 6500U 2.5GHz  16GB
# 1318         14.0  Intel Celeron Dual Core N3050 1.6GHz   2GB
# 1319         15.6            Intel Core i7 6500U 2.5GHz   6GB
# 1320         15.6  Intel Celeron Dual Core N3050 1.6GHz   4GB
#
#                                     Gpu       OpSys  Weight  Price_euros  \
# laptop_ID
# 1          Intel Iris Plus Graphics 640       macOS    1.37      1339.69
# 2                Intel HD Graphics 6000       macOS    1.34       898.94
# 3                 Intel HD Graphics 620       No OS    1.86       575.00
# 4                    AMD Radeon Pro 455       macOS    1.83      2537.45
# 5          Intel Iris Plus Graphics 650       macOS    1.37      1803.60
# ...                                 ...         ...     ...          ...
# 1316              Intel HD Graphics 520  Windows 10    1.80       638.00
# 1317              Intel HD Graphics 520  Windows 10    1.30      1499.00
# 1318                  Intel HD Graphics  Windows 10    1.50       229.00
# 1319                 AMD Radeon R5 M330  Windows 10    2.19       764.00
# 1320                  Intel HD Graphics  Windows 10    2.20       369.00
#
#                                            Cpu_Company  Memory_Amount  \
# laptop_ID
# 1                            [Intel, Core, i5, 2.3GHz]          128.0
# 2                            [Intel, Core, i5, 1.8GHz]          128.0
# 3                     [Intel, Core, i5, 7200U, 2.5GHz]          256.0
# 4                            [Intel, Core, i7, 2.7GHz]          512.0
# 5                            [Intel, Core, i5, 3.1GHz]          256.0
# ...                                                ...            ...
# 1316                  [Intel, Core, i7, 6500U, 2.5GHz]          128.0
# 1317                  [Intel, Core, i7, 6500U, 2.5GHz]          512.0
# 1318       [Intel, Celeron, Dual, Core, N3050, 1.6GHz]           64.0
# 1319                  [Intel, Core, i7, 6500U, 2.5GHz]         1024.0
# 1320       [Intel, Celeron, Dual, Core, N3050, 1.6GHz]          500.0
#
#           Memory_Type  SSD
# laptop_ID
# 1                 SSD    1
# 2               Flash    0
# 3                 SSD    1
# 4                 SSD    1
# 5                 SSD    1
# ...               ...  ...
# 1316              SSD    1
# 1317              SSD    1
# 1318            Flash    0
# 1319              HDD    0
# 1320              HDD    0
#
# [1303 rows x 14 columns]

# %% [markdown]
# 3.1 Присоедините к таблице clients данные по ноутбукам
# через метод join

# %%
df_laptop_join=client_laptop.join(df_laptop)
df_laptop_join.head()
# Out:
#            client_id Company            Product  TypeName  Inches  \
# laptop_id
# 506               45  Lenovo      ThinkPad L570  Notebook    15.6
# 398               32     NaN                NaN       NaN     NaN
# 710               67  Lenovo  IdeaPad 320-15ABR  Notebook    15.6
# 120               33    Dell      Inspiron 7570  Notebook    15.6
# 1999              43     NaN                NaN       NaN     NaN
#
#                                    Cpu  Ram                    Gpu  \
# laptop_id
# 506         Intel Core i5 7200U 2.5GHz  8GB  Intel HD Graphics 620
# 398                                NaN  NaN                    NaN
# 710        AMD A12-Series 9720P 3.6GHz  8GB          AMD Radeon R7
# 120         Intel Core i7 8550U 1.8GHz  8GB   Nvidia GeForce 940MX
# 1999                               NaN  NaN                    NaN
#
#                 OpSys  Weight  Price_euros                       Cpu_Company  \
# laptop_id
# 506        Windows 10    2.30       911.00  [Intel, Core, i5, 7200U, 2.5GHz]
# 398               NaN     NaN          NaN                               NaN
# 710        Windows 10    2.20       429.00  [AMD, A12-Series, 9720P, 3.6GHz]
# 120        Windows 10    2.16      1130.33  [Intel, Core, i7, 8550U, 1.8GHz]
# 1999              NaN     NaN          NaN                               NaN
#
#            Memory_Amount Memory_Type  SSD
# laptop_id
# 506                256.0         SSD  1.0
# 398                  NaN         NaN  NaN
# 710               1024.0         HDD  0.0
# 120                256.0         SSD  1.0
# 1999                 NaN         NaN  NaN

# %% [markdown]
# 3.2 Присоедините к таблице clients данные по ноутбукам
# через метод merge
# Это нужно, чтобы понимать, какие ноутбуки покупались клиентами

# %%
merged=df.merge(clients,left_on='laptop_ID',right_on='laptop_id')
merged.head()
# Out:
#    laptop_ID Company            Product  TypeName  Inches  \
# 0        120    Dell      Inspiron 7570  Notebook    15.6
# 1        506  Lenovo      ThinkPad L570  Notebook    15.6
# 2        710  Lenovo  IdeaPad 320-15ABR  Notebook    15.6
#
#                            Cpu  Ram                    Gpu       OpSys  \
# 0   Intel Core i7 8550U 1.8GHz  8GB   Nvidia GeForce 940MX  Windows 10
# 1   Intel Core i5 7200U 2.5GHz  8GB  Intel HD Graphics 620  Windows 10
# 2  AMD A12-Series 9720P 3.6GHz  8GB          AMD Radeon R7  Windows 10
#
#    Weight  Price_euros                       Cpu_Company  Memory_Amount  \
# 0    2.16      1130.33  [Intel, Core, i7, 8550U, 1.8GHz]          256.0
# 1    2.30       911.00  [Intel, Core, i5, 7200U, 2.5GHz]          256.0
# 2    2.20       429.00  [AMD, A12-Series, 9720P, 3.6GHz]         1024.0
#
#   Memory_Type  SSD  client_id  laptop_id
# 0         SSD    1         33        120
# 1         SSD    1         45        506
# 2         HDD    0         67        710

# %% [markdown]
# #Задание 4.
# Составьте несколько сводных таблиц
# 4.1 Найдите среднюю стоимость ноутбуков в зависимости
# от компании производителя
# Отсортируйте от меньшей стоимости к большей
# 4.2 Найдите минимальную, среднюю и максимальную
# стоимости ноутбуков в зависимости от производителя
# процессора
# 4.3 Постройте таблицу с подсчетом количества ноутбуков в
# данных в зависимости от производителя CPU и ОЗУ
# 4.4 Постройте таблицу с подсчетом средней стоимости
# ноутбуков в данных в зависимости от операционной
# системы и GB памяти

# %%
df.groupby('Company').agg({'Price_euros': 'mean'}).sort_values('Price_euros')
# Out:
#            Price_euros
# Company
# Vero        217.425000
# Mediacom    295.000000
# Chuwi       314.296667
# Acer        626.775825
# Fujitsu     729.000000
# HP         1067.774854
# Lenovo     1086.384444
# Asus       1104.169367
# Xiaomi     1133.462500
# Dell       1186.068990
# Toshiba    1267.812500
# Samsung    1413.444444
# Huawei     1424.000000
# Apple      1564.198571
# Microsoft  1612.308333
# Google     1677.666667
# MSI        1728.908148
# LG         2099.000000
# Razer      3346.142857

# %%
df.groupby('Cpu_Company').agg({'Price_euros':['min','max','mean']})
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[41], line 1
# ----> 1 df.groupby('Cpu_Company').agg({'Price_euros':['min','max','mean']})
#
# File c:\Users\ПК\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\groupby\generic.py:1269, in DataFrameGroupBy.aggregate(self, func, engine, engine_kwargs, *args, **kwargs)
#    1266 func = maybe_mangle_lambdas(func)
#    1268 op = GroupByApply(self, func, args, kwargs)
# -> 1269 result = op.agg()
#    1270 if not is_dict_like(func) and result is not None:
#    1271     return result
#
# File c:\Users\ПК\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\apply.py:163, in Apply.agg(self)
#     160     return self.apply_str()
#     162 if is_dict_like(arg):
# --> 163     return self.agg_dict_like()
#     164 elif is_list_like(arg):
#     165     # we require a list, but not a 'str'
#     166     return self.agg_list_like()
#
# File c:\Users\ПК\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\apply.py:420, in Apply.agg_dict_like(self)
#     417         results = {key: colg.agg(how) for key, how in arg.items()}
#     418     else:
#     419         # key used for column selection and output
# --> 420         results = {
#     421             key: obj._gotitem(key, ndim=1).agg(how) for key, how in arg.items()
#     422         }
#     424 # set the final keys
#     425 keys = list(arg.keys())
#
# File c:\Users\ПК\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\apply.py:421, in <dictcomp>(.0)
#     417         results = {key: colg.agg(how) for key, how in arg.items()}
#     418     else:
#     419         # key used for column selection and output
#     420         results = {
# --> 421             key: obj._gotitem(key, ndim=1).agg(how) for key, how in arg.items()
#     422         }
#     424 # set the final keys
#     425 keys = list(arg.keys())
#
# File c:\Users\ПК\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\groupby\generic.py:238, in SeriesGroupBy.aggregate(self, func, engine, engine_kwargs, *args, **kwargs)
#     234 elif isinstance(func, abc.Iterable):
#     235     # Catch instances of lists / tuples
#     236     # but not the class list / tuple itself.
#     237     func = maybe_mangle_lambdas(func)
# --> 238     ret = self._aggregate_multiple_funcs(func, *args, **kwargs)
#     239     if relabeling:
#     240         # columns is not narrowed by mypy from relabeling flag
#     241         assert columns is not None  # for mypy
#
# File c:\Users\ПК\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\groupby\generic.py:316, in SeriesGroupBy._aggregate_multiple_funcs(self, arg, *args, **kwargs)
#     314     for idx, (name, func) in enumerate(arg):
#     315         key = base.OutputKey(label=name, position=idx)
# --> 316         results[key] = self.aggregate(func, *args, **kwargs)
#     318 if any(isinstance(x, DataFrame) for x in results.values()):
#     319     from pandas import concat
#
# File c:\Users\ПК\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\groupby\generic.py:232, in SeriesGroupBy.aggregate(self, func, engine, engine_kwargs, *args, **kwargs)
#     229     kwargs = {}
#     231 if isinstance(func, str):
# --> 232     return getattr(self, func)(*args, **kwargs)
#     234 elif isinstance(func, abc.Iterable):
#     235     # Catch instances of lists / tuples
#     236     # but not the class list / tuple itself.
#     237     func = maybe_mangle_lambdas(func)
#
# File c:\Users\ПК\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\groupby\groupby.py:2293, in GroupBy.min(self, numeric_only, min_count, engine, engine_kwargs)
#    2291     return self._numba_agg_general(sliding_min_max, engine_kwargs, False)
#    2292 else:
# -> 2293     return self._agg_general(
#    2294         numeric_only=numeric_only,
#    2295         min_count=min_count,
#    2296         alias="min",
#    2297         npfunc=np.min,
#    2298     )
#
# File c:\Users\ПК\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\groupby\groupby.py:1422, in GroupBy._agg_general(self, numeric_only, min_count, alias, npfunc)
#    1413 @final
#    1414 def _agg_general(
#    1415     self,
#    (...)
#    1420     npfunc: Callable,
#    1421 ):
# -> 1422     result = self._cython_agg_general(
#    1423         how=alias,
#    1424         alt=npfunc,
#    1425         numeric_only=numeric_only,
#    1426         min_count=min_count,
#    1427     )
#    1428     return result.__finalize__(self.obj, method="groupby")
#
# File c:\Users\ПК\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\groupby\groupby.py:1507, in GroupBy._cython_agg_general(self, how, alt, numeric_only, min_count, **kwargs)
#    1503         result = self._agg_py_fallback(values, ndim=data.ndim, alt=alt)
#    1505     return result
# -> 1507 new_mgr = data.grouped_reduce(array_func)
#    1508 res = self._wrap_agged_manager(new_mgr)
#    1509 out = self._wrap_aggregated_output(res)
#
# File c:\Users\ПК\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\internals\base.py:197, in SingleDataManager.grouped_reduce(self, func)
#     195 def grouped_reduce(self, func):
#     196     arr = self.array
# --> 197     res = func(arr)
#     198     index = default_index(len(res))
#     200     mgr = type(self).from_array(res, index)
#
# File c:\Users\ПК\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\groupby\groupby.py:1490, in GroupBy._cython_agg_general.<locals>.array_func(values)
#    1488 def array_func(values: ArrayLike) -> ArrayLike:
#    1489     try:
# -> 1490         result = self.grouper._cython_operation(
#    1491             "aggregate",
#    1492             values,
#    1493             how,
#    1494             axis=data.ndim - 1,
#    1495             min_count=min_count,
#    1496             **kwargs,
#    1497         )
#    1498     except NotImplementedError:
#    1499         # generally if we have numeric_only=False
#    1500         # and non-applicable functions
#    1501         # try to python agg
#    1502         # TODO: shouldn't min_count matter?
#    1503         result = self._agg_py_fallback(values, ndim=data.ndim, alt=alt)
#
# File c:\Users\ПК\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\groupby\ops.py:955, in BaseGrouper._cython_operation(self, kind, values, how, axis, min_count, **kwargs)
#     950 """
#     951 Returns the values of a cython operation.
#     952 """
#     953 assert kind in ["transform", "aggregate"]
# --> 955 cy_op = WrappedCythonOp(kind=kind, how=how, has_dropped_na=self.has_dropped_na)
#     957 ids, _, _ = self.group_info
#     958 ngroups = self.ngroups
#
# File c:\Users\ПК\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\_libs\properties.pyx:36, in pandas._libs.properties.CachedProperty.__get__()
#
# File c:\Users\ПК\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\groupby\ops.py:869, in BaseGrouper.has_dropped_na(self)
#     863 @final
#     864 @cache_readonly
#     865 def has_dropped_na(self) -> bool:
#     866     """
#     867     Whether grouper has null value(s) that are dropped.
#     868     """
# --> 869     return bool((self.group_info[0] < 0).any())
#
# File c:\Users\ПК\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\_libs\properties.pyx:36, in pandas._libs.properties.CachedProperty.__get__()
#
# File c:\Users\ПК\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\groupby\ops.py:873, in BaseGrouper.group_info(self)
#     871 @cache_readonly
#     872 def group_info(self) -> tuple[npt.NDArray[np.intp], npt.NDArray[np.intp], int]:
# --> 873     comp_ids, obs_group_ids = self._get_compressed_codes()
#     875     ngroups = len(obs_group_ids)
#     876     comp_ids = ensure_platform_int(comp_ids)
#
# File c:\Users\ПК\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\groupby\ops.py:897, in BaseGrouper._get_compressed_codes(self)
#     894     # FIXME: compress_group_index's second return value is int64, not intp
#     896 ping = self.groupings[0]
# --> 897 return ping.codes, np.arange(len(ping.group_index), dtype=np.intp)
#
# File c:\Users\ПК\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\groupby\grouper.py:671, in Grouping.codes(self)
#     669 @property
#     670 def codes(self) -> npt.NDArray[np.signedinteger]:
# --> 671     return self._codes_and_uniques[0]
#
# File c:\Users\ПК\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\_libs\properties.pyx:36, in pandas._libs.properties.CachedProperty.__get__()
#
# File c:\Users\ПК\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\groupby\grouper.py:780, in Grouping._codes_and_uniques(self)
#     775     uniques = self._uniques
#     776 else:
#     777     # GH35667, replace dropna=False with use_na_sentinel=False
#     778     # error: Incompatible types in assignment (expression has type "Union[
#     779     # ndarray[Any, Any], Index]", variable has type "Categorical")
# --> 780     codes, uniques = algorithms.factorize(  # type: ignore[assignment]
#     781         self.grouping_vector, sort=self._sort, use_na_sentinel=self._dropna
#     782     )
#     783 return codes, uniques
#
# File c:\Users\ПК\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\algorithms.py:780, in factorize(values, sort, use_na_sentinel, size_hint)
#     777             # Don't modify (potentially user-provided) array
#     778             values = np.where(null_mask, na_value, values)
# --> 780     codes, uniques = factorize_array(
#     781         values,
#     782         use_na_sentinel=use_na_sentinel,
#     783         size_hint=size_hint,
#     784     )
#     786 if sort and len(uniques) > 0:
#     787     uniques, codes = safe_sort(
#     788         uniques,
#     789         codes,
#    (...)
#     792         verify=False,
#     793     )
#
# File c:\Users\ПК\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\algorithms.py:581, in factorize_array(values, use_na_sentinel, size_hint, na_value, mask)
#     578 hash_klass, values = _get_hashtable_algo(values)
#     580 table = hash_klass(size_hint or len(values))
# --> 581 uniques, codes = table.factorize(
#     582     values,
#     583     na_sentinel=-1,
#     584     na_value=na_value,
#     585     mask=mask,
#     586     ignore_na=use_na_sentinel,
#     587 )
#     589 # re-cast e.g. i8->dt64/td64, uint8->bool
#     590 uniques = _reconstruct_data(uniques, original.dtype, original)
#
# File pandas\_libs\hashtable_class_helper.pxi:7280, in pandas._libs.hashtable.PyObjectHashTable.factorize()
#
# File pandas\_libs\hashtable_class_helper.pxi:7194, in pandas._libs.hashtable.PyObjectHashTable._unique()
#
# TypeError: unhashable type: 'list'
